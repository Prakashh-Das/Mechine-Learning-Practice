# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakashh-Das/Mechine-Learning/blob/main/Linear_Regression_Hands_on.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
np.random.seed(42)

num_samples = 500

years_of_experience = np.random.randint(2, 21, size=num_samples)

slope = (200_000 - 60_000)/18
intercept = 60_000

salary = slope * years_of_experience + intercept + np.random.normal(0, 10_000, size=num_samples)

data = pd.DataFrame({'YearsOfExperience': years_of_experience, 'Salary': salary})

df = pd.DataFrame(data)

# %%
df
# Out:
#      YearsOfExperience         Salary
# 0                    8  115037.780010
# 1                   16  182309.972927
# 2                   12  156442.408989
# 3                    9  144753.562169
# 4                    8  130798.818454
# ..                 ...            ...
# 495                 18  203824.097462
# 496                  8  123886.744304
# 497                 14  173813.401529
# 498                  5  101780.575328
# 499                  5  123441.890288
#
# [500 rows x 2 columns]

# %%
df.describe()
# Out:
#        YearsOfExperience         Salary
# count         500.000000     500.000000
# mean           10.616000  142570.011096
# std             5.662922   44935.263058
# min             2.000000   54881.134555
# 25%             5.750000  104426.300731
# 50%            10.000000  139865.032545
# 75%            16.000000  182341.125962
# max            20.000000  241879.376204

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='YearsOfExperience', y='Salary', color='blue')
sns.regplot(data=df, x='YearsOfExperience', y='Salary', scatter=False, color='red')

plt.title('Relationship between Years of Experience and Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
x = df[['YearsOfExperience']]
y = df['Salary']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train, y_train)
# Out:
# 0.9488372177019488

# %%
model.score(x_test, y_test)
# Out:
# 0.9573704756930141

# %%
y_pred = model.predict(x_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 7905.114728709239

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 93933277.37947103

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9573704756930141

# %%
model.coef_
# Out:
# array([7696.61292305])

# %%
model.intercept_
# Out:
# 60961.340880280564

# %%
coefficient = model.coef_
intercept = model.intercept_

# %%
x = np.linspace(0, 20, 100)
y = coefficient * x + intercept

plt.scatter(x, y, label=f'y = {coefficient[0]:.2f}x + {intercept:.2f}')
plt.title('Relationship between Years of Experience and Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')
